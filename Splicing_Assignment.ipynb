# %%
#TEST_CODE
#########################################################################################
#Imports
from cairo import SVGSurface, Context, Matrix
from Bio import Seq
from itertools import product

import re
import sys
import os
import cairo 
import math
#########################################################################################
#Global Variables
name_list=[]
lines={}
seq_list=[] 
pattern_list=[]

fasta="/Users/mandiedriskill/Desktop/Spliceing_Assignment/Figure_1.fasta"
motifs="/Users/mandiedriskill/Desktop/Spliceing_Assignment/Fig_1_motifs.txt"
#########################################################################################
color_dict={"Blue":(0,0,205),"Cyan":(0,250,25),"Steel":(0,0,0), "Red":(255,0,0), "purple":(50,0,50), "yellow":(255,255,0),"Pink":(50,.5,.7), "Orange":(250,.4,.1), "Green":(0,.9,.3),"Dark Blue":(.094,.094,.42)}
colors=[*color_dict]
#print(colors)
#########################################################################################

def get_ambiguous(seq):
    d = Seq.IUPAC.IUPACData.ambiguous_dna_values
    ra = []
    for i in product(*[d[j] for j in seq]):
        ra.append("".join(i))
    return ra

#########################################################################################
#Exon and Motif Section
org_list=[]
motif_list=[]
with open(fasta, "r") as fa, open(motifs, "r") as mo:
    for mo_line in mo:
        mo_line=mo_line.strip("\n")
        #print(mo_line)
        motif_cap=mo_line.upper()
        #print("old",motif_cap)
        #print("new",motif_cap.replace("U", "T"))
        motif_cap=motif_cap.replace("U", "T")
        org_list.append(mo_line)
        #print(org_list)
        exon_motifs=get_ambiguous(motif_cap)
        #print("old",exon_motifs)
        motif_list.append(exon_motifs)
        #print("list", motif_list)
        

    for line in fa:
        line = line.strip()
        if line.startswith(">"):
            id = line
            lines[id] = " "
        else:
            lines[id] += line 

for header, seq in lines.items():
    seq_list.append(seq)
    #print(header)
    parts=header.split(" ")
    #print(parts)
    name=(parts[1])
    #print(name)
    name_list.append(name)
    line_length=len(seq)
    #print(line_length)

    pattern_exon='[A-Z]+'
    pattern_intron='[a-z]+'
    
    exon=re.findall(pattern_exon, seq)
    lengths=([len(i) for i in exon])
    #print("Exon lengths:",lengths)
    exons=[(m.start(0)) for m in re.finditer(pattern_exon, seq)]
    #print("Exons start position:",exons)
    
        #print(name)
    width=line_length+100
    height=500
    surface = cairo.SVGSurface(name+".svg", width, height)
    context = cairo.Context(surface)
    
    context.set_line_width(5)
    context.move_to(0,75) #(X,Y)
    context.line_to((line_length), 75)#Match above
    context.stroke()
    pat = cairo.LinearGradient(0.0, 0.0, 0.0, 1.0)
    pat.add_color_stop_rgba(0, .65, .65, .65, 1)

    #print("after",start)
    

    #print("pycairo exons:", exons)
    #print("pycairo exon_legnths:",lengths)
    for exon_starts,exon_lengths in zip(exons,lengths):
        context.rectangle(int(exon_starts), 25, int(exon_lengths), 100)
    #print(exon_starts)
    #print(exon_lengths)
        context.set_source(pat)
        context.fill()
        context.stroke()
        
    
    
    upper_seq=seq.upper()
    #print("capital seq:",upper_seq)
    #print(exon_motif_list)
    #print(motif_list)
    ctr=0
    for motif in motif_list:
        #print(motif)
        #print("crt",ctr)
        #print(colors[ctr])
        ctr_color=colors[ctr]
        #print(ctr_color)
        #print(color_list[ctr_color])
        motif_color=color_dict[ctr_color]
        #print(motif_color)
        #print(motif_color[0])
        pat1 = cairo.LinearGradient(0.0, 0.0, 0.0, 1)
        pat1.add_color_stop_rgba(1,motif_color[0],motif_color[1],motif_color[2], .5)
    
        legend_ctr=ctr*25
        #print(legend_ctr)
        context.rectangle(0,(180+legend_ctr),15,15)
        context.set_source(pat1)
        context.fill()
        context.select_font_face("pyrus", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
        context.set_font_size(20)
        #print(org_list)

        context.move_to(20, 195+ legend_ctr)
        context.set_source_rgb(0, 0, 0)
        #print(org_list)
        context.show_text(org_list[ctr])
        context.set_source(pat1)
        context.fill()
        context.stroke()
        
        ctr+=1
        #print(ctr)
        for item in motif:
            
        
            #print("new",item)
            
            pattern_motif=item
            #print("new",item)
            #print("new",pattern_motif)

            #print(upper_seq)
            motif_start=[(m.start(0)) for m in re.finditer(pattern_motif, upper_seq)]
            #print(motif_start)
            
            motif_lengths=re.findall(pattern_motif, upper_seq)
            #print(motif_lengths)
            motif_length=([len(i) for i in motif_lengths])
            #print(motif_length)
            
            #print(pattern_motif)


                
            for mo_start,mo_length in zip(motif_start,motif_length):
                #print(pattern_motif)
                #print(motif_start)

                context.rectangle(int(mo_start), 25, int(mo_length), 100)
            #print(mo_start)

            
            
            context.set_source(pat1)
            context.fill()
            context.stroke()
            
#legend
    context.rectangle(0,150,15,15)
    context.set_source(pat)
    context.fill()
    context.select_font_face("pyrus", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
    context.set_font_size(20)
    context.move_to(20, 165)
    context.set_source_rgb(0, 0, 0)
    context.show_text("Exon")

    context.move_to(100, 160)
    context.line_to(80,160)
    context.stroke()
    context.move_to(110, 165)
    context.show_text("Intron")
            
            
            

    surface.write_to_png("image_"+name)
# Out:
# new YGCY
# ['ygcy']
# old ['CGCC', 'CGCT', 'TGCC', 'TGCT']
# new GCATG
# ['ygcy', 'GCAUG']
# old ['GCATG']
# new CATAG
# ['ygcy', 'GCAUG', 'catag']
# old ['CATAG']
# new YYYYYYYYYY
# ['ygcy', 'GCAUG', 'catag', 'YYYYYYYYYY']
# old ['CCCCCCCCCC', 'CCCCCCCCCT', 'CCCCCCCCTC', 'CCCCCCCCTT', 'CCCCCCCTCC', 'CCCCCCCTCT', 'CCCCCCCTTC', 'CCCCCCCTTT', 'CCCCCCTCCC', 'CCCCCCTCCT', 'CCCCCCTCTC', 'CCCCCCTCTT', 'CCCCCCTTCC', 'CCCCCCTTCT', 'CCCCCCTTTC', 'CCCCCCTTTT', 'CCCCCTCCCC', 'CCCCCTCCCT', 'CCCCCTCCTC', 'CCCCCTCCTT', 'CCCCCTCTCC', 'CCCCCTCTCT', 'CCCCCTCTTC', 'CCCCCTCTTT', 'CCCCCTTCCC', 'CCCCCTTCCT', 'CCCCCTTCTC', 'CCCCCTTCTT', 'CCCCCTTTCC', 'CCCCCTTTCT', 'CCCCCTTTTC', 'CCCCCTTTTT', 'CCCCTCCCCC', 'CCCCTCCCCT', 'CCCCTCCCTC', 'CCCCTCCCTT', 'CCCCTCCTCC', 'CCCCTCCTCT', 'CCCCTCCTTC', 'CCCCTCCTTT', 'CCCCTCTCCC', 'CCCCTCTCCT', 'CCCCTCTCTC', 'CCCCTCTCTT', 'CCCCTCTTCC', 'CCCCTCTTCT', 'CCCCTCTTTC', 'CCCCTCTTTT', 'CCCCTTCCCC', 'CCCCTTCCCT', 'CCCCTTCCTC', 'CCCCTTCCTT', 'CCCCTTCTCC', 'CCCCTTCTCT', 'CCCCTTCTTC', 'CCCCTTCTTT', 'CCCCTTTCCC', 'CCCCTTTCCT', 'CCCCTTTCTC', 'CCCCTTTCTT', 'CCCCTTTTCC', 'CCCCTTTTCT', 'CCCCTTTTTC', 'CCCCTTTTTT', 'CCCTCCCCCC', 'CCCTCCCCCT', 'CCCTCCCCTC', 'CCCTCCCCTT', 'CCCTCCCTCC', 'CCCTCCCTCT', 'CCCTCCCTTC', 'CCCTCCCTTT', 'CCCTCCTCCC', 'CCCTCCTCCT', 'CCCTCCTCTC', 'CCCTCCTCTT', 'CCCTCCTTCC', 'CCCTCCTTCT', 'CCCTCCTTTC', 'CCCTCCTTTT', 'CCCTCTCCCC', 'CCCTCTCCCT', 'CCCTCTCCTC', 'CCCTCTCCTT', 'CCCTCTCTCC', 'CCCTCTCTCT', 'CCCTCTCTTC', 'CCCTCTCTTT', 'CCCTCTTCCC', 'CCCTCTTCCT', 'CCCTCTTCTC', 'CCCTCTTCTT', 'CCCTCTTTCC', 'CCCTCTTTCT', 'CCCTCTTTTC', 'CCCTCTTTTT', 'CCCTTCCCCC', 'CCCTTCCCCT', 'CCCTTCCCTC', 'CCCTTCCCTT', 'CCCTTCCTCC', 'CCCTTCCTCT', 'CCCTTCCTTC', 'CCCTTCCTTT', 'CCCTTCTCCC', 'CCCTTCTCCT', 'CCCTTCTCTC', 'CCCTTCTCTT', 'CCCTTCTTCC', 'CCCTTCTTCT', 'CCCTTCTTTC', 'CCCTTCTTTT', 'CCCTTTCCCC', 'CCCTTTCCCT', 'CCCTTTCCTC', 'CCCTTTCCTT', 'CCCTTTCTCC', 'CCCTTTCTCT', 'CCCTTTCTTC', 'CCCTTTCTTT', 'CCCTTTTCCC', 'CCCTTTTCCT', 'CCCTTTTCTC', 'CCCTTTTCTT', 'CCCTTTTTCC', 'CCCTTTTTCT', 'CCCTTTTTTC', 'CCCTTTTTTT', 'CCTCCCCCCC', 'CCTCCCCCCT', 'CCTCCCCCTC', 'CCTCCCCCTT', 'CCTCCCCTCC', 'CCTCCCCTCT', 'CCTCCCCTTC', 'CCTCCCCTTT', 'CCTCCCTCCC', 'CCTCCCTCCT', 'CCTCCCTCTC', 'CCTCCCTCTT', 'CCTCCCTTCC', 'CCTCCCTTCT', 'CCTCCCTTTC', 'CCTCCCTTTT', 'CCTCCTCCCC', 'CCTCCTCCCT', 'CCTCCTCCTC', 'CCTCCTCCTT', 'CCTCCTCTCC', 'CCTCCTCTCT', 'CCTCCTCTTC', 'CCTCCTCTTT', 'CCTCCTTCCC', 'CCTCCTTCCT', 'CCTCCTTCTC', 'CCTCCTTCTT', 'CCTCCTTTCC', 'CCTCCTTTCT', 'CCTCCTTTTC', 'CCTCCTTTTT', 'CCTCTCCCCC', 'CCTCTCCCCT', 'CCTCTCCCTC', 'CCTCTCCCTT', 'CCTCTCCTCC', 'CCTCTCCTCT', 'CCTCTCCTTC', 'CCTCTCCTTT', 'CCTCTCTCCC', 'CCTCTCTCCT', 'CCTCTCTCTC', 'CCTCTCTCTT', 'CCTCTCTTCC', 'CCTCTCTTCT', 'CCTCTCTTTC', 'CCTCTCTTTT', 'CCTCTTCCCC', 'CCTCTTCCCT', 'CCTCTTCCTC', 'CCTCTTCCTT', 'CCTCTTCTCC', 'CCTCTTCTCT', 'CCTCTTCTTC', 'CCTCTTCTTT', 'CCTCTTTCCC', 'CCTCTTTCCT', 'CCTCTTTCTC', 'CCTCTTTCTT', 'CCTCTTTTCC', 'CCTCTTTTCT', 'CCTCTTTTTC', 'CCTCTTTTTT', 'CCTTCCCCCC', 'CCTTCCCCCT', 'CCTTCCCCTC', 'CCTTCCCCTT', 'CCTTCCCTCC', 'CCTTCCCTCT', 'CCTTCCCTTC', 'CCTTCCCTTT', 'CCTTCCTCCC', 'CCTTCCTCCT', 'CCTTCCTCTC', 'CCTTCCTCTT', 'CCTTCCTTCC', 'CCTTCCTTCT', 'CCTTCCTTTC', 'CCTTCCTTTT', 'CCTTCTCCCC', 'CCTTCTCCCT', 'CCTTCTCCTC', 'CCTTCTCCTT', 'CCTTCTCTCC', 'CCTTCTCTCT', 'CCTTCTCTTC', 'CCTTCTCTTT', 'CCTTCTTCCC', 'CCTTCTTCCT', 'CCTTCTTCTC', 'CCTTCTTCTT', 'CCTTCTTTCC', 'CCTTCTTTCT', 'CCTTCTTTTC', 'CCTTCTTTTT', 'CCTTTCCCCC', 'CCTTTCCCCT', 'CCTTTCCCTC', 'CCTTTCCCTT', 'CCTTTCCTCC', 'CCTTTCCTCT', 'CCTTTCCTTC', 'CCTTTCCTTT', 'CCTTTCTCCC', 'CCTTTCTCCT', 'CCTTTCTCTC', 'CCTTTCTCTT', 'CCTTTCTTCC', 'CCTTTCTTCT', 'CCTTTCTTTC', 'CCTTTCTTTT', 'CCTTTTCCCC', 'CCTTTTCCCT', 'CCTTTTCCTC', 'CCTTTTCCTT', 'CCTTTTCTCC', 'CCTTTTCTCT', 'CCTTTTCTTC', 'CCTTTTCTTT', 'CCTTTTTCCC', 'CCTTTTTCCT', 'CCTTTTTCTC', 'CCTTTTTCTT', 'CCTTTTTTCC', 'CCTTTTTTCT', 'CCTTTTTTTC', 'CCTTTTTTTT', 'CTCCCCCCCC', 'CTCCCCCCCT', 'CTCCCCCCTC', 'CTCCCCCCTT', 'CTCCCCCTCC', 'CTCCCCCTCT', 'CTCCCCCTTC', 'CTCCCCCTTT', 'CTCCCCTCCC', 'CTCCCCTCCT', 'CTCCCCTCTC', 'CTCCCCTCTT', 'CTCCCCTTCC', 'CTCCCCTTCT', 'CTCCCCTTTC', 'CTCCCCTTTT', 'CTCCCTCCCC', 'CTCCCTCCCT', 'CTCCCTCCTC', 'CTCCCTCCTT', 'CTCCCTCTCC', 'CTCCCTCTCT', 'CTCCCTCTTC', 'CTCCCTCTTT', 'CTCCCTTCCC', 'CTCCCTTCCT', 'CTCCCTTCTC', 'CTCCCTTCTT', 'CTCCCTTTCC', 'CTCC ...

# %%
#Actual_CODE

#!/usr/bin/env python

#########################################################################################
#Imports
from cairo import SVGSurface, Context, Matrix
from Bio import Seq
from itertools import product

import argparse
import re
import sys
import os
import cairo 
import math
#########################################################################################
def get_arguments():
    parser = argparse.ArgumentParser(description="This is a program that takes two arguments: a FASTA file and a simple text file with a list of up to 10 motifs.  Returns an PNG and SVG files (one per fasta intry) illustrating where the Exon, introns, and motifs are in each fasta entry")
    parser.add_argument("-f","--fasta_file", help="-f <path><file>, Requires a fasta file, assumes sequences are in the correct orientation",required=True,type=str)
    parser.add_argument("-m","--motif_file", help="-m <path><file>, Requires a simple text file, each line is a motif",required=True,type=str)

    return parser.parse_args()

args = get_arguments()
fasta_file = args.fasta_file #fasta file
motif_file = args.motif_file #motif

#########################################################################################
#Global Variables

lines={}
org_list=[]
motif_list=[]

#fasta="/Users/mandiedriskill/Desktop/Spliceing_Assignment/INSR.fasta"
#motifs="/Users/mandiedriskill/Desktop/Spliceing_Assignment/test_motif.txt"
#########################################################################################
#dictionaries

color_dict={"Blue":(0,0,205),"Cyan":(0,250,25),"Steel":(0,0,0), "Red":(255,0,0), "purple":(50,0,50), "yellow":(255,255,0),"Pink":(50,.5,.7), "Orange":(250,.4,.1), "Green":(0,.9,.3),"Dark Blue":(.094,.094,.42)}
colors=[*color_dict]
#########################################################################################
#fuctions
def get_ambiguous(seq):
    d = Seq.IUPAC.IUPACData.ambiguous_dna_values
    ra = []
    for i in product(*[d[j] for j in seq]):
        ra.append("".join(i))
    return ra

#########################################################################################
#Exon and Motif Plotting


with open(fasta_file, "r") as fa, open(motif_file, "r") as mo:
    for mo_line in mo:
        mo_line=mo_line.strip("\n")
        motif_cap=mo_line.upper()
        motif_cap=motif_cap.replace("U", "T")
        org_list.append(mo_line)
        exon_motifs=get_ambiguous(motif_cap)
        motif_list.append(exon_motifs)
        

    for line in fa:
        line = line.strip()
        if line.startswith(">"):
            id = line
            lines[id] = " "
        else:
            lines[id] += line 

for header, seq in lines.items():
    parts=header.split()
	name=parts[1]
	line_length=len(seq)
	pattern_exon='[A-Z]+'
	pattern_intron='[a-z]+'
	exon=re.findall(pattern_exon, seq)
	lengths=([len(i) for i in exon])
	exons=[(m.start(0)) for m in re.finditer(pattern_exon, seq)]
    
	width=line_length+100
	height=500
	surface = cairo.SVGSurface(name+".svg", width, height)
	context = cairo.Context(surface)
    
	context.set_line_width(5)
	context.move_to(0,75) #(X,Y)
	context.line_to((line_length), 75)#Match above
	context.stroke()
	pat = cairo.LinearGradient(0.0, 0.0, 0.0, 1.0)
	pat.add_color_stop_rgba(0, .65, .65, .65, 1)

    

	for exon_starts,exon_lengths in zip(exons,lengths):
		context.rectangle(int(exon_starts), 25, int(exon_lengths), 100)
		context.set_source(pat)
		context.fill()
		context.stroke()
        
	upper_seq=seq.upper()

	ctr=0
	for motif in motif_list:
		ctr_color=colors[ctr]
		motif_color=color_dict[ctr_color]
        
		pat1 = cairo.LinearGradient(0.0, 0.0, 0.0, 1)
		pat1.add_color_stop_rgba(1,motif_color[0],motif_color[1],motif_color[2], .5)
    
		legend_ctr=ctr*25
		context.rectangle(0,(180+legend_ctr),15,15)
		context.set_source(pat1)
		context.fill()
		context.select_font_face("pyrus", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
		context.set_font_size(20)

		context.move_to(20, 195+ legend_ctr)
		context.set_source_rgb(0, 0, 0)
		context.show_text(org_list[ctr])
		context.set_source(pat1)
		context.fill()
		context.stroke()
        
		ctr+=1
		for item in motif:            
			pattern_motif=item
			motif_start=[(m.start(0)) for m in re.finditer(pattern_motif, upper_seq)]            
			motif_lengths=re.findall(pattern_motif, upper_seq)
			motif_length=([len(i) for i in motif_lengths])
			for mo_start,mo_length in zip(motif_start,motif_length):
				context.rectangle(int(mo_start), 25, int(mo_length), 100)

			context.set_source(pat1)
			context.fill()
			context.stroke()
            
	context.rectangle(0,150,15,15)
	context.set_source(pat)
	context.fill()
	context.select_font_face("pyrus", cairo.FONT_SLANT_NORMAL, cairo.FONT_WEIGHT_NORMAL)
	context.set_font_size(20)
	context.move_to(20, 165)
	context.set_source_rgb(0, 0, 0)
	context.show_text("Exon")

	context.move_to(100, 160)
	context.line_to(80,160)
	context.stroke()
	context.move_to(110, 165)
	context.show_text("Intron")
	
	surface.write_to_png(name+".png")
